# %%
#Importing library
from bs4 import BeautifulSoup
import requests
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
#Clicking on the website
url='https://www.zomato.com/bangalore/restaurants'
browser=webdriver.Chrome()
browser.get(url)

# %%
#Extracting the html content
html=browser.page_source
soup=BeautifulSoup(html,'html.parser')

# %%
#Printing the html content
soup
# Out:
# <html data-rh="lang" lang="en"><head>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="https://googleads.g.doubleclick.net" rel="preconnect"/>
# <link href="https://jumbo.zomato.com" rel="preconnect"/>
# <link href="https://accounts.google.com" rel="preconnect"/>
# <link href="https://securepubads.g.doubleclick.net" rel="preconnect"/>
# <link href="https://www.google-analytics.com" rel="preconnect"/>
# <link href="https://www.googleadservices.com" rel="preconnect"/>
# <link href="https://bat.bing.com" rel="preconnect"/>
# <link href="https://8391443.fls.doubleclick.net" rel="preconnect"/>
# <title>Restaurants in Bengaluru - Zomato</title>
# ...

# %%
#creating empty list to fill the data in it
restaurant_name=[]
ratings=[]
price_for_one=[]
cuisins=[]
link=[]

#Extracting the Restaurant details
for i in soup.find_all('h4',{'class':'sc-1hp8d8a-0 sc-imDdex fdjWVR'}):
    restaurant_name.append(i.text)
for j in soup.find_all('div',{'class':'sc-1q7bklc-1 cILgox'}):
    ratings.append(j.text)
for k in soup.find_all('p',{'class':'sc-1hez2tp-0 sc-lffWgi liHDRm'}):
    price_for_one.append(k.text)
for m in soup.find_all('p',{'class':'sc-1hez2tp-0 sc-lffWgi hyoGXE'}):
    cuisins.append(m.text)
for l in soup.find_all('a', href = True):
    if 'order' in l['href']:
        if l['href'] not in link:
            
            link.append(l['href'])

# %%
#Jumping on the extracting links to find out the delivery and locations deatils
delivery_review_no=[]
locations=[]
count = 0
for i in link:
    count+=1
    print(count,end=" ")
    r=browser.get('https://www.zomato.com/'+i)
    sou = BeautifulSoup(browser.page_source, 'lxml')
    #location Deatils
    try:
        j = sou.find_all("a",{"class" : "sc-clNaTc vNCcy"})
        locations.append(j[0].text)
    except:
        locations.append('NA')
        
    #Delivery Details  
    try:
        j = sou.find_all("div",{"class" : "sc-1q7bklc-8 kEgyiI"})
        delivery_review_no.append(j[0].text)
    except:
        delivery_review_no.append('NA')

# %%
#Making the length of all list equal 
max_length = max(len(restaurant_name), len(ratings), len(price_for_one), len(cuisins), len(link), len(locations), len(delivery_review_no))

restaurant_name += [None] * (max_length - len(restaurant_name))
ratings += [None] * (max_length - len(ratings))
price_for_one += [None] * (max_length - len(price_for_one))
cuisins += [None] * (max_length - len(cuisins))
link += [None] * (max_length - len(link))
locations += [None] * (max_length - len(locations))
delivery_review_no += [None] * (max_length - len(delivery_review_no))

#Creating the dataframe
data = {'restaurant_name':restaurant_name,'ratings':ratings,'price_for_one':price_for_one,'cuisins':cuisins,'links':link,
    'locations': locations,'delivery_review_no':delivery_review_no}
df = pd.DataFrame(data)


print(df)
# Out:
#     restaurant_name ratings price_for_one  \
# 0         Pizza Hut     4.1  ₹200 for one
# 1               KFC     4.4  ₹200 for one
# 2        McDonald's     4.1  ₹200 for one
# 3       Burger King     4.2  ₹200 for one
# 4     Meghana Foods     3.7  ₹200 for one
# ..              ...     ...           ...
# 776            None     3.6          None
# 777            None     3.8          None
# 778            None     3.4          None
# 779            None     3.6          None
# 780            None     3.4          None
#
#                                                cuisins  \
# 0    Pizza, Italian, Pasta, Fast Food, Desserts, Be...
# 1      Fast Food, Burger, Biryani, Desserts, Beverages
# 2                                    Burger, Fast Food
# 3               Burger, Fast Food, Desserts, Beverages
# 4               Biryani, Andhra, North Indian, Seafood
# ..                                                 ...
# 776                                               None
# ...

# %%
df
# Out:
#     restaurant_name ratings price_for_one  \
# 0         Pizza Hut     4.1  ₹200 for one
# 1               KFC     4.4  ₹200 for one
# 2        McDonald's     4.1  ₹200 for one
# 3       Burger King     4.2  ₹200 for one
# 4     Meghana Foods     3.7  ₹200 for one
# ..              ...     ...           ...
# 776            None     3.6          None
# 777            None     3.8          None
# 778            None     3.4          None
# 779            None     3.6          None
# 780            None     3.4          None
#
#                                                cuisins  \
# 0    Pizza, Italian, Pasta, Fast Food, Desserts, Be...
# 1      Fast Food, Burger, Biryani, Desserts, Beverages
# 2                                    Burger, Fast Food
# 3               Burger, Fast Food, Desserts, Beverages
# 4               Biryani, Andhra, North Indian, Seafood
# ..                                                 ...
# 776                                               None
# ...

# %%
# Downloading the Scrapped data
df.to_excel("zomato2.xlsx", index=False)
